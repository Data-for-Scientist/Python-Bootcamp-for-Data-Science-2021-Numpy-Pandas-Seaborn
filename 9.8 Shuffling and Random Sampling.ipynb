# %% [markdown]
# ![title](img/cover4.png)

# %% [markdown]
# <center><em>Copyright! This material is protected, please do not copy or distribute.    by:Taher Assaf</em></center>

# %% [markdown]
# ***
# <h1 align="center">Udemy course : Python Bootcamp for Data Science 2021 Numpy Pandas & Seaborn</h1>
#
# ***

# %% [markdown]
# ## 9.8 Shuffling and Random Sampling

# %% [markdown]
# First we import numpy and pandas library:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Here we create a simple series 10 integers using numpy function **random.randint()**:

# %%
ser1 = pd.Series(np.random.randint(20, size =10))
ser1
# Out:
# 0    10
# 1     8
# 2    17
# 3     4
# 4    16
# 5     5
# 6     7
# 7    15
# 8     4
# 9    12
# dtype: int32

# %% [markdown]
# We can randomly shuffle the values in this series using the function **sample()**:

# %%
ser1.sample(frac=1)
# Out:
# 1     8
# 8     4
# 4    16
# 3     4
# 9    12
# 6     7
# 0    10
# 7    15
# 2    17
# 5     5
# dtype: int32

# %% [markdown]
# The index can be sorted again after the shuffling using the function **reset_index()**:

# %%
ser1 = ser1.sample(frac=1).reset_index(drop=True)
ser1
# Out:
# 0     4
# 1     8
# 2    15
# 3     4
# 4    17
# 5     5
# 6    16
# 7    12
# 8    10
# 9     7
# dtype: int32

# %% [markdown]
# To take a random sample or a random subset of your dataset we change the argument **frac** into the desired fraction, here we choose 50% of the data:

# %%
sample1 = ser1.sample(frac= .5)
sample1
# Out:
# 2    15
# 8    10
# 9     7
# 3     4
# 7    12
# dtype: int32

# %%
sample1 = ser1.sample(frac =0.5).reset_index(drop=True)
sample1
# Out:
# 0     4
# 1    10
# 2     5
# 3     8
# 4     4
# dtype: int32

# %% [markdown]
# Here we read a dataframe from a csv file using the function **pd.read_csv()**:

# %%
data = pd.read_csv('data/ex3.csv')
data
# Out:
#       year  age      sex            maritl      race        education  \
# 0     2006   18  1. Male  1. Never Married  1. White     1. < HS Grad
# 1     2004   24  1. Male  1. Never Married  1. White  4. College Grad
# 2     2003   45  1. Male        2. Married  1. White  3. Some College
# 3     2003   43  1. Male        2. Married  3. Asian  4. College Grad
# 4     2005   50  1. Male       4. Divorced  1. White       2. HS Grad
# ...    ...  ...      ...               ...       ...              ...
# 2995  2008   44  1. Male        2. Married  1. White  3. Some College
# 2996  2007   30  1. Male        2. Married  1. White       2. HS Grad
# 2997  2005   27  1. Male        2. Married  2. Black     1. < HS Grad
# 2998  2005   27  1. Male  1. Never Married  1. White  3. Some College
# 2999  2009   55  1. Male      5. Separated  1. White       2. HS Grad
#
#             wage
# 0      75.043154
# 1      70.476020
# 2     130.982177
# 3     154.685293
# 4      75.043154
# ...

# %% [markdown]
# To select a random sample with 20% of this dataframe, we set the fraction argument to be **frac = 0.2**:

# %%
sample2 = data.sample(frac =0.2)
sample2
# Out:
#       year  age      sex            maritl      race           education  \
# 2713  2008   57  1. Male        2. Married  1. White          2. HS Grad
# 2801  2007   45  1. Male        2. Married  1. White     4. College Grad
# 1823  2006   22  1. Male  1. Never Married  1. White     4. College Grad
# 358   2009   41  1. Male       4. Divorced  1. White  5. Advanced Degree
# 2482  2004   49  1. Male  1. Never Married  4. Other        1. < HS Grad
# ...    ...  ...      ...               ...       ...                 ...
# 763   2006   31  1. Male        2. Married  1. White     4. College Grad
# 1128  2005   45  1. Male       4. Divorced  1. White          2. HS Grad
# 1850  2003   27  1. Male      5. Separated  1. White     3. Some College
# 2442  2004   40  1. Male        2. Married  1. White          2. HS Grad
# 2280  2004   58  1. Male        2. Married  1. White     3. Some College
#
#             wage
# 2713   82.682399
# 2801  130.983694
# 1823  114.475713
# 358    38.605915
# ...

# %% [markdown]
# Also here the index can be sorted using the function **reset_index()**:

# %%
sample3 = data.sample(frac =0.2).reset_index(drop=True)
sample3
# Out:
#      year  age      sex            maritl      race           education  \
# 0    2008   23  1. Male        2. Married  1. White     4. College Grad
# 1    2005   54  1. Male        2. Married  1. White          2. HS Grad
# 2    2003   57  1. Male        2. Married  1. White     4. College Grad
# 3    2007   50  1. Male  1. Never Married  1. White          2. HS Grad
# 4    2009   50  1. Male  1. Never Married  1. White  5. Advanced Degree
# ..    ...  ...      ...               ...       ...                 ...
# 595  2007   59  1. Male        2. Married  1. White     4. College Grad
# 596  2004   63  1. Male        2. Married  1. White          2. HS Grad
# 597  2003   49  1. Male  1. Never Married  1. White     4. College Grad
# 598  2006   28  1. Male      5. Separated  1. White        1. < HS Grad
# 599  2006   29  1. Male        2. Married  1. White     3. Some College
#
#            wage
# 0     36.673704
# 1    158.173662
# 2    268.266292
# 3     50.411923
# ...

# %% [markdown]
# We can also select a random sample based on the number of rows rather than fraction, here we choose a sybset of 100 rows:

# %%
sample4 = data.sample(n=100).reset_index(drop=True)
sample4
# Out:
#     year  age      sex            maritl      race           education  \
# 0   2003   45  1. Male        2. Married  1. White     4. College Grad
# 1   2007   43  1. Male        2. Married  1. White          2. HS Grad
# 2   2006   51  1. Male        2. Married  2. Black          2. HS Grad
# 3   2003   20  1. Male  1. Never Married  1. White          2. HS Grad
# 4   2004   54  1. Male        2. Married  1. White          2. HS Grad
# ..   ...  ...      ...               ...       ...                 ...
# 95  2008   54  1. Male        2. Married  3. Asian          2. HS Grad
# 96  2007   32  1. Male        2. Married  1. White        1. < HS Grad
# 97  2009   57  1. Male        2. Married  1. White  5. Advanced Degree
# 98  2004   33  1. Male        2. Married  1. White     4. College Grad
# 99  2003   40  1. Male        2. Married  1. White          2. HS Grad
#
#           wage
# 0   133.232351
# 1    65.110854
# 2    94.072715
# 3    75.355679
# 4    94.072715
# ..         ...
# ...

# %% [markdown]
# ***
#
# <h1 align="center">Thank You</h1>
#
# ***
